# %% [markdown]
# # PYTHON INTRODUTION

# %% [markdown]
# -code today nd everyday

# %%
print("hello,world!")
# Out:
# hello,world!

# %%
age = 20
print("age")
# Out:
# age

# %%
age = 20
print(age)
# Out:
# 20

# %%
age = 20
age = 30
print(age)
# Out:
# 30

# %% [markdown]
# # STRING

# %% [markdown]
# useing the string values

# %%
age = 20 
price = 19.95 #float value
first_name = "Nitk" #stingvalue with varialbe name that helps to read code 
is_online = False #boolean value
print(age)
# Out:
# 20

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Patient_name = "john smith"
age = 20
Patient  = "New"
print(Patient_name,age,Patient)
# Out:
# john smith 20 New

# %% [markdown]
# # How to get input from user

# %%
name = input("WHT IS UR NAME?") # useing INPUT function
print("Hello_" + name)
# Out:
# WHT IS UR NAME?Nitik
# Hello_Nitik

# %%
birth_year = input("Enter your birth year")
age = 2020 - int(birth_year)
print(age)

# %%
birth_year = input("Enter your birth year:")
age = 2020 - int(birth_year)
print(age)
# Out:
# Enter your birth year:2009
# 11

# %%
print("+----------------+")
print("|/t Python  /t   |")
print("+----------------+")
# Out:
# +----------------+
# |/t Python  /t   |
# +----------------+

# %%
print("+----------------+")
print("|     Python     |")
print("+----------------+")
# Out:
# +----------------+
# |     Python     |
# +----------------+

# %%
int()
float()
bool()
str()
# Out:
# ''

# %%
a = float(input("add first number :"))
b = int(input("add second nummber :"))
sum = a + b
print(sum)
# Out:
# add first number :12.4
# add second nummber :12
# 24.4

# %% [markdown]
# # strings

# %%
course = "pyhton for beginners"
print(course.upper())
# Out:
# PYHTON FOR BEGINNERS

# %%
course = "pyhton for beginners"
print(course.upper())
print(course)
# Out:
# PYHTON FOR BEGINNERS
# pyhton for beginners

# %%
course = "pyhton for beginners"
print(course.find('y'))
# Out:
# 1

# %%
course = "pyhton for beginners"
print(course.replace("for","###"))
# Out:
# pyhton ### beginners

# %%
course = "pyhton for beginners"
print(course.find('python'))
# Out:
# -1

# %%
course = "pyhton for beginners"
print("pyhton" in course)
# Out:
# True

# %% [markdown]
# # Arithmetic opertions

# %%
a = float(input('enter no ; '))
b = float(input('enter no ; '))
print (a/b)
print (a*b)
print (a-b)
print (a+b)
print (a//b)
print (a**b)
# Out:
# enter no ; 12
# enter no ; 6
# 2.0
# 72.0
# 6.0
# 18.0
# 2.0
# 2985984.0

# %% [raw]
# # OPERATOR PRECEDENCE

# %%
x = 10 + 3 * 2
print(x)
# Out:
# 16

# %%
x = (10 + 3 )* 2
print(x)

# %%
##### Comapriosn opperatiors (imp)


>=
>=
<
>
==
!=

# %% [raw]
# ### logical operators

# %% [markdown]
# ![image.png](attachment:image.png)
